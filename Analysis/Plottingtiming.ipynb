# %%
import numpy as np 
import pandas as pd 
import plot_utils
import matplotlib.pyplot as plt 


df = pd.read_csv("../Data/time.txt", sep='        ')

df.col
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return func(*args, **kwargs)
#                      Dimensions      Particles    Metro-steps       Eq-steps     StepLength  \
# 3 3   1000000 100000                             0.10000 17531772.00000
#   5   1000000 100000                             0.10000 34327576.00000
#   7   1000000 100000                             0.10000 49805195.00000
#   9   1000000 100000                             0.10000 63637402.00000
#   11  1000000 100000                             0.10000 82495667.00000
#   13  1000000 100000                             0.10000 97191420.00000
#   15  1000000 100000                             0.10000117933028.00000
# ...

# %%
df = df[['Time', 'Particles']]

plt.plot(df)
